# %% [markdown]
# # TР 2

# %% [markdown]
# ## Exercice 1: Exploration de l'environnement FrozenLake

# %%
import gymnasium as gym
import numpy as np

# Charger l’environnement FrozenLake
env = gym.make("FrozenLake-v1", is_slippery=True)

# Afficher l’espace d’états et d’actions
print("\n" + "=" * 50)
print("🌨️ INITIALISATION DE L'ENVIRONNEMENT FROZEN LAKE")
print("=" * 50)
print(f"🔲 Espace d'états : {env.observation_space}")
print(f"🎮 Espace d'actions : {env.action_space}")
print("=" * 50)

num_episodes = 20  

for episode in range(num_episodes):
    print(f"\n🔵 Épisode {episode + 1}")
    observation, info = env.reset()
    done = False
    step = 0

    while not done:
        action = env.action_space.sample()  # Action aléatoire
        new_observation, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        step += 1

        # Affichage des informations de chaque étape
        print(f"\n🔹 Étape {step} :")
        print(f"  ➡️ État actuel      : {observation}")
        print(f"  🎮 Action choisie    : {action}")
        print(f"  🔄 Nouvel état       : {new_observation}")
        print(f"  🏆 Récompense reçue : {reward}")
        print("-" * 30)
        observation = new_observation

    print(f"✅ Épisode {episode + 1} terminé en {step} étapes")

env.close()
# Out:
# ==================================================
# 🌨️ INITIALISATION DE L'ENVIRONNEMENT FROZEN LAKE
# ==================================================
# 🔲 Espace d'états : Discrete(16)
# 🎮 Espace d'actions : Discrete(4)
# ==================================================
#
# 🔵 Épisode 1
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 6 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 7 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 8 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 9 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 10 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 11 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 12 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 13 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 14 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 1 terminé en 14 étapes
#
# 🔵 Épisode 2
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 8
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 8
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 9
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 9
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 10
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 10
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 11
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 2 terminé en 5 étapes
#
# 🔵 Épisode 3
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 2
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 2
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 2
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 2
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 3 terminé en 5 étapes
#
# 🔵 Épisode 4
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 4 terminé en 2 étapes
#
# 🔵 Épisode 5
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 6 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 2
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 7 :
#   ➡️ État actuel      : 2
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 8 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 9 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 10 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 5 terminé en 10 étapes
#
# 🔵 Épisode 6
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 6 terminé en 2 étapes
#
# 🔵 Épisode 7
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 7 terminé en 4 étapes
#
# 🔵 Épisode 8
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 8 terminé en 2 étapes
#
# 🔵 Épisode 9
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 9 terminé en 2 étapes
#
# 🔵 Épisode 10
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 6 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 7 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 8 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 9 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 10 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 11 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 12 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 13 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 14 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 8
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 15 :
#   ➡️ État actuel      : 8
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 12
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 10 terminé en 15 étapes
#
# 🔵 Épisode 11
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 6 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 11 terminé en 6 étapes
#
# 🔵 Épisode 12
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 12 terminé en 2 étapes
#
# 🔵 Épisode 13
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 13 terminé en 5 étapes
#
# 🔵 Épisode 14
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 8
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 8
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 8
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 8
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 9
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 9
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 8
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 6 :
#   ➡️ État actuel      : 8
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 7 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 8
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 8 :
#   ➡️ État actuel      : 8
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 9 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 10 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 11 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 14 terminé en 11 étapes
#
# 🔵 Épisode 15
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 8
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 8
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 9
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 9
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 15 terminé en 4 étapes
#
# 🔵 Épisode 16
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 2
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 2
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 6
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 6
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 7
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 16 terminé en 4 étapes
#
# 🔵 Épisode 17
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 6 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 7 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 8 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 2
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 9 :
#   ➡️ État actuel      : 2
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 6
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 10 :
#   ➡️ État actuel      : 6
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 7
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 17 terminé en 10 étapes
#
# 🔵 Épisode 18
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 18 terminé en 2 étapes
#
# 🔵 Épisode 19
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 6 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 7 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 8 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 8
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 9 :
#   ➡️ État actuel      : 8
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 8
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 10 :
#   ➡️ État actuel      : 8
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 11 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 12 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 13 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 14 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 15 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 16 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 2
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 17 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 19 terminé en 17 étapes
#
# 🔵 Épisode 20
#
# 🔹 Étape 1 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 2 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 3 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 4 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 4
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 5 :
#   ➡️ État actuel      : 4
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 6 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 3
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 7 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 0
#   🔄 Nouvel état       : 0
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 8 :
#   ➡️ État actuel      : 0
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 1
#   🏆 Récompense reçue : 0.0
# ------------------------------
#
# 🔹 Étape 9 :
#   ➡️ État actuel      : 1
#   🎮 Action choisie    : 1
#   🔄 Nouvel état       : 5
#   🏆 Récompense reçue : 0.0
# ------------------------------
# ✅ Épisode 20 terminé en 9 étapes

# %% [markdown]
# ## Exercice 2: Implémenintion de la Q-Table et Initialisation

# %%
# Charger l’environnement
env = gym.make("FrozenLake-v1", is_slippery=True)

# Récupérer le nombre d'états et d'actions
num_states = env.observation_space.n
num_actions = env.action_space.n

# Initialisation de la Q-table à 0
q_table = np.zeros((num_states, num_actions))

# Affichage des dimensions
print(f"Nombre d’états : {num_states}")
print(f"Nombre d’actions : {num_actions}")

# Affichage de la Q-table initiale
print("\n Q-Table initialisée")
print("\n Vérification des valeurs Q par état :")
for state in range(num_states):
    print(f"État {state} → Valeurs Q : {q_table[state]}")
# Out:
# Nombre d’états : 16
# Nombre d’actions : 4
#
#  Q-Table initialisée
#
#  Vérification des valeurs Q par état :
# État 0 → Valeurs Q : [0. 0. 0. 0.]
# État 1 → Valeurs Q : [0. 0. 0. 0.]
# État 2 → Valeurs Q : [0. 0. 0. 0.]
# État 3 → Valeurs Q : [0. 0. 0. 0.]
# État 4 → Valeurs Q : [0. 0. 0. 0.]
# État 5 → Valeurs Q : [0. 0. 0. 0.]
# État 6 → Valeurs Q : [0. 0. 0. 0.]
# État 7 → Valeurs Q : [0. 0. 0. 0.]
# État 8 → Valeurs Q : [0. 0. 0. 0.]
# État 9 → Valeurs Q : [0. 0. 0. 0.]
# État 10 → Valeurs Q : [0. 0. 0. 0.]
# État 11 → Valeurs Q : [0. 0. 0. 0.]
# État 12 → Valeurs Q : [0. 0. 0. 0.]
# État 13 → Valeurs Q : [0. 0. 0. 0.]
# État 14 → Valeurs Q : [0. 0. 0. 0.]
# État 15 → Valeurs Q : [0. 0. 0. 0.]

# %% [markdown]
# ## Exercice 3: Implémentation du Q-Learning avec Mise à Jour

# %%
# Création de l’environnement
env = gym.make("FrozenLake-v1", is_slippery=True)
num_states = env.observation_space.n
num_actions = env.action_space.n

# Q-table initialisée à 0
q_table = np.zeros((num_states, num_actions))

# Hyperparamètres
alpha = 0.1            # Taux d’apprentissage
gamma = 0.9            # Facteur de discount
epsilon = 1.0          # Niveau d’exploration initial
epsilon_decay = 0.995  # Décroissance d’epsilon
min_epsilon = 0.01
num_episodes = 1000    # Nombre d’épisodes d’apprentissage

# Apprentissage
for episode in range(num_episodes):
    state, info = env.reset()
    done = False

    while not done:
        # Choisir action (ε-greedy)
        if np.random.rand() < epsilon:
            action = env.action_space.sample()  # Action aléatoire
        else:
            action = np.argmax(q_table[state])  # Action selon la Q-table

        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated

        # Mise à jour de la Q-table (formule Q-learning)
        best_next_action = np.max(q_table[next_state])
        q_table[state, action] = q_table[state, action] + alpha * (
            reward + gamma * best_next_action - q_table[state, action]
        )

        state = next_state

    # Mise à jour de epsilon (exploration diminue)
    epsilon = max(min_epsilon, epsilon * epsilon_decay)

# Affichage de la Q-table finale
print("\n Q-Table après apprentissage :")
print(q_table)
# Out:
#  Q-Table après apprentissage :
# [[5.01414211e-02 2.90444837e-02 3.03862285e-02 3.08806404e-02]
#  [1.11471499e-02 7.39327629e-03 2.45977717e-03 4.03364202e-03]
#  [1.64800689e-04 3.17166025e-02 2.21915516e-03 2.92068142e-05]
#  [1.36931938e-09 9.09458592e-03 1.10846383e-05 1.52314520e-07]
#  [6.28999975e-02 3.52756428e-02 3.81706419e-02 3.73433496e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [5.98231426e-02 0.00000000e+00 3.52977455e-02 6.24594229e-09]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [3.53961890e-02 5.24558358e-02 5.65361162e-02 9.95433250e-02]
#  [7.09619857e-02 5.65391973e-02 1.33875075e-01 5.97150741e-02]
#  [2.33164711e-01 1.23239641e-01 8.90382616e-02 4.24677059e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.14023538e-01 6.96638761e-02 2.74928777e-01 1.14002598e-01]
#  [1.52928180e-01 5.91511726e-01 3.73056189e-01 2.94286593e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]]

# %% [markdown]
# # Exercices 4: Évaluation des Performances de l'Agent

# %%
num_test_episodes = 50
successes = 0

for episode in range(num_test_episodes):
    state, info = env.reset()
    done = False

    while not done:
        # Action optimale selon la Q-table
        action = np.argmax(q_table[state])
        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        state = next_state

        if done and reward == 1.0:
            successes += 1

# Taux de réussite
success_rate = (successes / num_test_episodes) * 100
print(f"\n✅ L’agent a réussi à atteindre l’objectif {successes} fois sur {num_test_episodes}.")
print(f"🎯 Taux de réussite : {success_rate:.2f} %")
# Out:
# ✅ L’agent a réussi à atteindre l’objectif 17 fois sur 50.
# 🎯 Taux de réussite : 34.00 %
