# %% [markdown]
# # ТР 3

# %% [markdown]
# ## Exercice 1: Decouvrire l'environnement

# %%
import numpy as np
from traffic_env import TrafficEnvironment
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 🚦 Initial Traffic Light Simulation 🚦
# State Format: [Cars North, Cars South, Cars East, Cars West]
# Actions: 0 = Keep Current Light, 1 = Switch Light
# Initial state: [6 2 0 4] (NS Green, EW Red)
# Step 1:
#   ➡ Action Taken: 0 (Keep)
#   🚥 Light Status: NS Green, EW Red
#   🏎 Cars State: [2 1 2 6]
#   🎯 Reward (Cars Passed): 5
# ----------------------------------------
# Step 2:
#   ➡ Action Taken: 0 (Keep)
#   🚥 Light Status: NS Green, EW Red
#   🏎 Cars State: [2 1 4 8]
#   🎯 Reward (Cars Passed): 2
# ----------------------------------------
# Step 3:
#   ➡ Action Taken: 0 (Keep)
#   🚥 Light Status: NS Green, EW Red
#   🏎 Cars State: [1 1 5 9]
#   🎯 Reward (Cars Passed): 2
# ----------------------------------------
# Step 4:
#   ➡ Action Taken: 0 (Keep)
#   🚥 Light Status: NS Green, EW Red
#   🏎 Cars State: [ 1  0  6 10]
#   🎯 Reward (Cars Passed): 2
# ----------------------------------------
# Step 5:
#   ➡ Action Taken: 0 (Keep)
#   🚥 Light Status: NS Green, EW Red
#   🏎 Cars State: [ 2  1  8 12]
#   🎯 Reward (Cars Passed): 1
# ----------------------------------------
# Step 6:
#   ➡ Action Taken: 0 (Keep)
#   🚥 Light Status: NS Green, EW Red
#   🏎 Cars State: [ 2  2 10 12]
#   🎯 Reward (Cars Passed): 3
# ----------------------------------------
# Step 7:
#   ➡ Action Taken: 0 (Keep)
#   🚥 Light Status: NS Green, EW Red
#   🏎 Cars State: [ 0  2 10 13]
#   🎯 Reward (Cars Passed): 3
# ----------------------------------------
# Step 8:
#   ➡ Action Taken: 0 (Keep)
#   🚥 Light Status: NS Green, EW Red
#   🏎 Cars State: [ 2  1 10 14]
#   🎯 Reward (Cars Passed): 2
# ----------------------------------------
# Step 9:
#   ➡ Action Taken: 0 (Keep)
#   🚥 Light Status: NS Green, EW Red
#   🏎 Cars State: [ 2  1 12 15]
#   🎯 Reward (Cars Passed): 3
# ----------------------------------------
# Step 10:
#   ➡ Action Taken: 0 (Keep)
#   🚥 Light Status: NS Green, EW Red
#   🏎 Cars State: [ 0  2 14 15]
#   🎯 Reward (Cars Passed): 2
# ----------------------------------------

# %%
from traffic_env import TrafficEnvironment

env = TrafficEnvironment ()
state = env.reset ()

for _ in range(10):
    action = 0 # Garder le feu tel qu'il est
    next_state, reward = env.step(action)
    print (f"État : {next_state}, Récompense : {reward}")
# Out:
# État : [1 7 3 4], Récompense : 3
# État : [2 6 3 4], Récompense : 3
# État : [0 2 5 5], Récompense : 6
# État : [2 2 5 7], Récompense : 2
# État : [1 2 7 7], Récompense : 4
# État : [0 2 8 8], Récompense : 2
# État : [ 2  3  9 10], Récompense : 1
# État : [ 2  0 10 10], Récompense : 5
# État : [ 1  1 12 10], Récompense : 1
# État : [ 2  2 12 11], Récompense : 2

# %% [markdown]
# ## Exercice 2: Implementation de Q-Learning

# %%
import numpy as np
from traffic_env import TrafficEnvironment

# Initialisation de la Q-Table : dimensions [N, S, E, W, actions]
q_table = np.zeros((10, 10, 10, 10, 2))


def train_q_learning(env, episodes=1000, alpha=0.1, gamma=0.9, epsilon=1.0, decay=0.995, min_epsilon=0.01):
    global q_table

    for episode in range(episodes):
        state = env.reset()
        state = np.clip(state, 0, 9)  # Empêcher les débordements
        done = False

        for step in range(100):  # Limite de pas par épisode
            n, s, e, w = state

            # ε-greedy : choisir action
            if np.random.rand() < epsilon:
                action = np.random.choice([0, 1])
            else:
                action = np.argmax(q_table[n, s, e, w])

            # Effectuer l'action
            next_state, reward = env.step(action)
            next_state = np.clip(next_state, 0, 9)
            n2, s2, e2, w2 = next_state

            # Mise à jour Q-Learning
            best_next = np.max(q_table[n2, s2, e2, w2])
            q_table[n, s, e, w, action] += alpha * (
                reward + gamma * best_next - q_table[n, s, e, w, action]
            )

            # Passer à l'état suivant
            state = next_state

        # Réduire epsilon (moins d'exploration)
        epsilon = max(min_epsilon, epsilon * decay)

    print("\n✅ Entraînement terminé.")
    return q_table


env = TrafficEnvironment()
q_table = train_q_learning(env, episodes=1000)

# Affichage amélioré de la Q-table
print("\n Extrait de la Q-table après apprentissage :")
for n in range(0, 10, 3):
    for s in range(0, 10, 3):
        for e in range(0, 10, 3):
            for w in range(0, 10, 3):
                actions_values = q_table[n, s, e, w]
                print(f"État [{n},{s},{e},{w}] → Gauche: {actions_values[0]:.2f}, Droite: {actions_values[1]:.2f}")
# Out:
# ✅ Entraînement terminé.
#
#  Extrait de la Q-table après apprentissage :
# État [0,0,0,0] → Gauche: 0.67, Droite: 18.06
# État [0,0,0,3] → Gauche: 2.80, Droite: 18.40
# État [0,0,0,6] → Gauche: 1.23, Droite: 4.97
# État [0,0,0,9] → Gauche: 0.00, Droite: 0.00
# État [0,0,3,0] → Gauche: 2.66, Droite: 19.37
# État [0,0,3,3] → Gauche: 5.56, Droite: 23.60
# État [0,0,3,6] → Gauche: 1.00, Droite: 12.66
# État [0,0,3,9] → Gauche: 0.21, Droite: 2.29
# État [0,0,6,0] → Gauche: 2.77, Droite: 0.00
# État [0,0,6,3] → Gauche: 0.21, Droite: 21.09
# État [0,0,6,6] → Gauche: 0.00, Droite: 7.89
# État [0,0,6,9] → Gauche: 0.11, Droite: 6.23
# État [0,0,9,0] → Gauche: 0.10, Droite: 0.00
# État [0,0,9,3] → Gauche: 0.16, Droite: 6.03
# État [0,0,9,6] → Gauche: 0.05, Droite: 4.90
# État [0,0,9,9] → Gauche: 0.82, Droite: 10.35
# État [0,3,0,0] → Gauche: 2.82, Droite: 19.91
# État [0,3,0,3] → Gauche: 9.43, Droite: 0.00
# État [0,3,0,6] → Gauche: 0.00, Droite: 0.00
# État [0,3,0,9] → Gauche: 0.00, Droite: 0.00
# État [0,3,3,0] → Gauche: 1.41, Droite: 11.92
# État [0,3,3,3] → Gauche: 0.34, Droite: 14.48
# État [0,3,3,6] → Gauche: 0.00, Droite: 3.35
# État [0,3,3,9] → Gauche: 0.40, Droite: 0.00
# État [0,3,6,0] → Gauche: 0.00, Droite: 0.00
# État [0,3,6,3] → Gauche: 2.75, Droite: 0.00
# État [0,3,6,6] → Gauche: 1.17, Droite: 0.00
# État [0,3,6,9] → Gauche: 0.00, Droite: 0.00
# État [0,3,9,0] → Gauche: 0.00, Droite: 0.00
# État [0,3,9,3] → Gauche: 0.86, Droite: 0.00
# État [0,3,9,6] → Gauche: 1.05, Droite: 0.00
# État [0,3,9,9] → Gauche: 0.00, Droite: 0.00
# État [0,6,0,0] → Gauche: 1.59, Droite: 0.00
# État [0,6,0,3] → Gauche: 1.42, Droite: 0.00
# État [0,6,0,6] → Gauche: 0.35, Droite: 0.00
# État [0,6,0,9] → Gauche: 0.00, Droite: 0.00
# État [0,6,3,0] → Gauche: 0.94, Droite: 0.00
# État [0,6,3,3] → Gauche: 0.00, Droite: 0.00
# État [0,6,3,6] → Gauche: 0.00, Droite: 0.00
# État [0,6,3,9] → Gauche: 0.43, Droite: 0.00
# État [0,6,6,0] → Gauche: 0.00, Droite: 0.00
# État [0,6,6,3] → Gauche: 0.48, Droite: 0.00
# État [0,6,6,6] → Gauche: 0.00, Droite: 0.00
# État [0,6,6,9] → Gauche: 0.00, Droite: 0.00
# État [0,6,9,0] → Gauche: 0.00, Droite: 0.00
# État [0,6,9,3] → Gauche: 0.00, Droite: 0.00
# État [0,6,9,6] → Gauche: 0.00, Droite: 0.00
# État [0,6,9,9] → Gauche: 0.20, Droite: 0.00
# État [0,9,0,0] → Gauche: 0.00, Droite: 0.00
# État [0,9,0,3] → Gauche: 0.00, Droite: 0.00
# État [0,9,0,6] → Gauche: 0.00, Droite: 0.00
# État [0,9,0,9] → Gauche: 0.00, Droite: 0.00
# État [0,9,3,0] → Gauche: 0.20, Droite: 0.00
# État [0,9,3,3] → Gauche: 0.30, Droite: 0.00
# État [0,9,3,6] → Gauche: 0.00, Droite: 0.00
# État [0,9,3,9] → Gauche: 0.00, Droite: 0.00
# État [0,9,6,0] → Gauche: 0.10, Droite: 0.00
# État [0,9,6,3] → Gauche: 0.00, Droite: 0.00
# État [0,9,6,6] → Gauche: 0.44, Droite: 0.00
# État [0,9,6,9] → Gauche: 0.43, Droite: 0.00
# État [0,9,9,0] → Gauche: 0.00, Droite: 0.00
# État [0,9,9,3] → Gauche: 0.00, Droite: 0.00
# État [0,9,9,6] → Gauche: 0.00, Droite: 0.00
# État [0,9,9,9] → Gauche: 0.00, Droite: 0.00
# État [3,0,0,0] → Gauche: 2.87, Droite: 19.11
# État [3,0,0,3] → Gauche: 0.00, Droite: 8.92
# État [3,0,0,6] → Gauche: 0.00, Droite: 0.00
# État [3,0,0,9] → Gauche: 0.10, Droite: 0.00
# État [3,0,3,0] → Gauche: 0.00, Droite: 12.34
# État [3,0,3,3] → Gauche: 2.81, Droite: 13.66
# État [3,0,3,6] → Gauche: 2.47, Droite: 0.00
# État [3,0,3,9] → Gauche: 0.48, Droite: 0.00
# État [3,0,6,0] → Gauche: 0.00, Droite: 0.00
# État [3,0,6,3] → Gauche: 0.20, Droite: 0.00
# État [3,0,6,6] → Gauche: 0.50, Droite: 0.00
# État [3,0,6,9] → Gauche: 0.30, Droite: 0.00
# État [3,0,9,0] → Gauche: 0.00, Droite: 0.00
# État [3,0,9,3] → Gauche: 0.38, Droite: 0.00
# État [3,0,9,6] → Gauche: 0.00, Droite: 0.00
# État [3,0,9,9] → Gauche: 0.88, Droite: 0.00
# État [3,3,0,0] → Gauche: 5.50, Droite: 23.49
# État [3,3,0,3] → Gauche: 0.00, Droite: 16.71
# État [3,3,0,6] → Gauche: 0.10, Droite: 0.44
# État [3,3,0,9] → Gauche: 0.92, Droite: 0.00
# État [3,3,3,0] → Gauche: 0.62, Droite: 14.76
# État [3,3,3,3] → Gauche: 15.24, Droite: 0.00
# État [3,3,3,6] → Gauche: 0.46, Droite: 0.00
# État [3,3,3,9] → Gauche: 0.00, Droite: 0.00
# État [3,3,6,0] → Gauche: 1.52, Droite: 0.00
# État [3,3,6,3] → Gauche: 1.63, Droite: 0.00
# État [3,3,6,6] → Gauche: 0.00, Droite: 0.75
# État [3,3,6,9] → Gauche: 0.00, Droite: 1.52
# État [3,3,9,0] → Gauche: 0.00, Droite: 0.00
# État [3,3,9,3] → Gauche: 0.00, Droite: 0.00
# État [3,3,9,6] → Gauche: 1.35, Droite: 0.00
# État [3,3,9,9] → Gauche: 0.64, Droite: 2.01
# État [3,6,0,0] → Gauche: 0.55, Droite: 16.45
# État [3,6,0,3] → Gauche: 0.00, Droite: 0.00
# État [3,6,0,6] → Gauche: 0.00, Droite: 0.00
# État [3,6,0,9] → Gauche: 0.00, Droite: 0.00
# État [3,6,3,0] → Gauche: 0.37, Droite: 0.85
# État [3,6,3,3] → Gauche: 3.28, Droite: 0.00
# État [3,6,3,6] → Gauche: 0.00, Droite: 0.00
# État [3,6,3,9] → Gauche: 0.00, Droite: 0.00
# État [3,6,6,0] → Gauche: 0.10, Droite: 0.00
# État [3,6,6,3] → Gauche: 0.79, Droite: 0.00
# État [3,6,6,6] → Gauche: 0.00, Droite: 0.00
# État [3,6,6,9] → Gauche: 1.13, Droite: 0.00
# État [3,6,9,0] → Gauche: 0.00, Droite: 0.00
# État [3,6,9,3] → Gauche: 0.00, Droite: 0.00
# État [3,6,9,6] → Gauche: 0.00, Droite: 0.00
# État [3,6,9,9] → Gauche: 0.00, Droite: 0.00
# État [3,9,0,0] → Gauche: 1.15, Droite: 0.00
# État [3,9,0,3] → Gauche: 0.00, Droite: 0.81
# État [3,9,0,6] → Gauche: 0.00, Droite: 0.00
# État [3,9,0,9] → Gauche: 0.00, Droite: 0.00
# État [3,9,3,0] → Gauche: 0.40, Droite: 0.00
# État [3,9,3,3] → Gauche: 0.00, Droite: 0.00
# État [3,9,3,6] → Gauche: 0.00, Droite: 0.00
# État [3,9,3,9] → Gauche: 0.94, Droite: 0.00
# État [3,9,6,0] → Gauche: 0.00, Droite: 0.00
# État [3,9,6,3] → Gauche: 0.00, Droite: 0.00
# État [3,9,6,6] → Gauche: 0.00, Droite: 0.00
# État [3,9,6,9] → Gauche: 0.00, Droite: 0.00
# État [3,9,9,0] → Gauche: 0.00, Droite: 0.00
# État [3,9,9,3] → Gauche: 0.00, Droite: 0.00
# État [3,9,9,6] → Gauche: 0.00, Droite: 0.00
# État [3,9,9,9] → Gauche: 0.00, Droite: 0.00
# État [6,0,0,0] → Gauche: 0.05, Droite: 1.64
# État [6,0,0,3] → Gauche: 0.33, Droite: 0.00
# État [6,0,0,6] → Gauche: 0.00, Droite: 0.00
# État [6,0,0,9] → Gauche: 0.00, Droite: 0.00
# État [6,0,3,0] → Gauche: 0.29, Droite: 0.00
# État [6,0,3,3] → Gauche: 1.59, Droite: 0.00
# État [6,0,3,6] → Gauche: 0.47, Droite: 0.00
# État [6,0,3,9] → Gauche: 0.00, Droite: 0.00
# État [6,0,6,0] → Gauche: 0.00, Droite: 0.00
# État [6,0,6,3] → Gauche: 0.00, Droite: 0.00
# État [6,0,6,6] → Gauche: 0.00, Droite: 0.00
# État [6,0,6,9] → Gauche: 0.46, Droite: 0.00
# État [6,0,9,0] → Gauche: 0.00, Droite: 0.00
# État [6,0,9,3] → Gauche: 0.00, Droite: 0.00
# État [6,0,9,6] → Gauche: 0.00, Droite: 0.00
# État [6,0,9,9] → Gauche: 0.36, Droite: 0.00
# État [6,3,0,0] → Gauche: 0.05, Droite: 8.77
# État [6,3,0,3] → Gauche: 0.37, Droite: 0.00
# État [6,3,0,6] → Gauche: 0.30, Droite: 0.00
# État [6,3,0,9] → Gauche: 0.00, Droite: 0.00
# État [6,3,3,0] → Gauche: 0.00, Droite: 1.63
# État [6,3,3,3] → Gauche: 0.00, Droite: 0.00
# État [6,3,3,6] → Gauche: 0.00, Droite: 0.00
# État [6,3,3,9] → Gauche: 0.00, Droite: 0.00
# État [6,3,6,0] → Gauche: 0.00, Droite: 0.00
# État [6,3,6,3] → Gauche: 0.00, Droite: 0.00
# État [6,3,6,6] → Gauche: 1.16, Droite: 0.00
# État [6,3,6,9] → Gauche: 0.00, Droite: 0.00
# État [6,3,9,0] → Gauche: 0.61, Droite: 0.00
# État [6,3,9,3] → Gauche: 0.00, Droite: 0.00
# État [6,3,9,6] → Gauche: 0.79, Droite: 0.00
# État [6,3,9,9] → Gauche: 1.98, Droite: 0.00
# État [6,6,0,0] → Gauche: 0.00, Droite: 5.48
# État [6,6,0,3] → Gauche: 0.00, Droite: 0.30
# État [6,6,0,6] → Gauche: 0.00, Droite: 0.20
# État [6,6,0,9] → Gauche: 0.40, Droite: 0.00
# État [6,6,3,0] → Gauche: 0.30, Droite: 0.00
# État [6,6,3,3] → Gauche: 0.40, Droite: 0.00
# État [6,6,3,6] → Gauche: 0.00, Droite: 0.00
# État [6,6,3,9] → Gauche: 0.00, Droite: 0.00
# État [6,6,6,0] → Gauche: 0.00, Droite: 0.00
# État [6,6,6,3] → Gauche: 0.00, Droite: 0.00
# État [6,6,6,6] → Gauche: 0.00, Droite: 0.00
# État [6,6,6,9] → Gauche: 0.00, Droite: 0.00
# État [6,6,9,0] → Gauche: 0.00, Droite: 0.00
# État [6,6,9,3] → Gauche: 0.00, Droite: 0.00
# État [6,6,9,6] → Gauche: 0.00, Droite: 0.00
# État [6,6,9,9] → Gauche: 0.00, Droite: 0.00
# État [6,9,0,0] → Gauche: 0.00, Droite: 3.52
# État [6,9,0,3] → Gauche: 1.14, Droite: 0.00
# État [6,9,0,6] → Gauche: 0.00, Droite: 0.00
# État [6,9,0,9] → Gauche: 0.29, Droite: 0.00
# État [6,9,3,0] → Gauche: 0.88, Droite: 0.00
# État [6,9,3,3] → Gauche: 0.00, Droite: 0.00
# État [6,9,3,6] → Gauche: 0.00, Droite: 0.00
# État [6,9,3,9] → Gauche: 0.00, Droite: 0.00
# État [6,9,6,0] → Gauche: 0.00, Droite: 0.00
# État [6,9,6,3] → Gauche: 0.00, Droite: 0.00
# État [6,9,6,6] → Gauche: 0.00, Droite: 0.00
# État [6,9,6,9] → Gauche: 1.06, Droite: 0.00
# État [6,9,9,0] → Gauche: 0.30, Droite: 0.00
# État [6,9,9,3] → Gauche: 0.00, Droite: 0.00
# État [6,9,9,6] → Gauche: 0.65, Droite: 0.00
# État [6,9,9,9] → Gauche: 0.00, Droite: 0.00
# État [9,0,0,0] → Gauche: 0.00, Droite: 0.00
# État [9,0,0,3] → Gauche: 0.00, Droite: 0.00
# État [9,0,0,6] → Gauche: 0.40, Droite: 0.00
# État [9,0,0,9] → Gauche: 0.40, Droite: 0.00
# État [9,0,3,0] → Gauche: 0.40, Droite: 0.00
# État [9,0,3,3] → Gauche: 0.00, Droite: 0.00
# État [9,0,3,6] → Gauche: 0.00, Droite: 0.00
# État [9,0,3,9] → Gauche: 0.00, Droite: 0.00
# État [9,0,6,0] → Gauche: 0.00, Droite: 0.00
# État [9,0,6,3] → Gauche: 0.00, Droite: 0.00
# État [9,0,6,6] → Gauche: 0.00, Droite: 0.00
# État [9,0,6,9] → Gauche: 0.00, Droite: 0.00
# État [9,0,9,0] → Gauche: 0.00, Droite: 0.00
# État [9,0,9,3] → Gauche: 0.00, Droite: 0.00
# État [9,0,9,6] → Gauche: 0.00, Droite: 0.00
# État [9,0,9,9] → Gauche: 0.00, Droite: 0.00
# État [9,3,0,0] → Gauche: 1.80, Droite: 0.00
# État [9,3,0,3] → Gauche: 0.00, Droite: 0.00
# État [9,3,0,6] → Gauche: 0.00, Droite: 0.00
# État [9,3,0,9] → Gauche: 0.00, Droite: 0.00
# État [9,3,3,0] → Gauche: 0.00, Droite: 0.00
# État [9,3,3,3] → Gauche: 0.75, Droite: 0.00
# État [9,3,3,6] → Gauche: 0.00, Droite: 0.20
# État [9,3,3,9] → Gauche: 0.00, Droite: 0.00
# État [9,3,6,0] → Gauche: 0.47, Droite: 0.00
# État [9,3,6,3] → Gauche: 0.00, Droite: 0.00
# État [9,3,6,6] → Gauche: 0.00, Droite: 0.00
# État [9,3,6,9] → Gauche: 0.00, Droite: 0.00
# État [9,3,9,0] → Gauche: 0.30, Droite: 0.00
# État [9,3,9,3] → Gauche: 0.00, Droite: 0.00
# État [9,3,9,6] → Gauche: 0.00, Droite: 0.00
# État [9,3,9,9] → Gauche: 0.00, Droite: 0.00
# État [9,6,0,0] → Gauche: 0.33, Droite: 5.34
# État [9,6,0,3] → Gauche: 0.57, Droite: 0.00
# État [9,6,0,6] → Gauche: 0.00, Droite: 0.00
# État [9,6,0,9] → Gauche: 0.00, Droite: 0.00
# État [9,6,3,0] → Gauche: 0.00, Droite: 0.00
# État [9,6,3,3] → Gauche: 0.00, Droite: 0.00
# État [9,6,3,6] → Gauche: 0.00, Droite: 0.00
# État [9,6,3,9] → Gauche: 0.00, Droite: 0.00
# État [9,6,6,0] → Gauche: 0.00, Droite: 0.20
# État [9,6,6,3] → Gauche: 0.00, Droite: 0.00
# État [9,6,6,6] → Gauche: 0.84, Droite: 0.00
# État [9,6,6,9] → Gauche: 0.00, Droite: 0.00
# État [9,6,9,0] → Gauche: 0.00, Droite: 0.00
# État [9,6,9,3] → Gauche: 0.00, Droite: 0.00
# État [9,6,9,6] → Gauche: 0.00, Droite: 0.00
# État [9,6,9,9] → Gauche: 0.00, Droite: 0.00
# État [9,9,0,0] → Gauche: 0.13, Droite: 6.03
# État [9,9,0,3] → Gauche: 1.04, Droite: 0.00
# État [9,9,0,6] → Gauche: 0.00, Droite: 0.00
# État [9,9,0,9] → Gauche: 0.30, Droite: 0.00
# État [9,9,3,0] → Gauche: 0.28, Droite: 0.00
# État [9,9,3,3] → Gauche: 0.00, Droite: 0.00
# État [9,9,3,6] → Gauche: 0.00, Droite: 0.00
# État [9,9,3,9] → Gauche: 0.89, Droite: 0.00
# État [9,9,6,0] → Gauche: 0.50, Droite: 0.00
# État [9,9,6,3] → Gauche: 0.00, Droite: 0.00
# État [9,9,6,6] → Gauche: 0.00, Droite: 0.00
# État [9,9,6,9] → Gauche: 0.00, Droite: 0.00
# État [9,9,9,0] → Gauche: 0.00, Droite: 0.00
# État [9,9,9,3] → Gauche: 0.00, Droite: 0.00
# État [9,9,9,6] → Gauche: 0.00, Droite: 0.00
# État [9,9,9,9] → Gauche: 0.00, Droite: 0.00

# %% [markdown]
# ## Exercice 3 : Implémentation de SARSA

# %%
import numpy as np
from traffic_env import TrafficEnvironment

# Nouvelle Q-table pour SARSA
q_sarsa = np.zeros((10, 10, 10, 10, 2))

def train_sarsa(env, episodes=1000, alpha=0.1, gamma=0.9, epsilon=1.0, decay=0.995, min_epsilon=0.01):
    global q_sarsa

    for episode in range(episodes):
        state = env.reset()
        state = np.clip(state, 0, 9)
        n, s, e, w = state

        # Choisir action initiale
        action = np.random.choice([0, 1]) if np.random.rand() < epsilon else np.argmax(q_sarsa[n, s, e, w])

        for step in range(100):
            next_state, reward = env.step(action)
            next_state = np.clip(next_state, 0, 9)
            n2, s2, e2, w2 = next_state

            # Choisir action suivante (SARSA)
            next_action = np.random.choice([0, 1]) if np.random.rand() < epsilon else np.argmax(q_sarsa[n2, s2, e2, w2])

            # Mise à jour SARSA
            q_sarsa[n, s, e, w, action] += alpha * (
                reward + gamma * q_sarsa[n2, s2, e2, w2, next_action] - q_sarsa[n, s, e, w, action]
            )

            # Mise à jour état/action
            state = next_state
            n, s, e, w = state
            action = next_action

        # Réduction d’epsilon
        epsilon = max(min_epsilon, epsilon * decay)

    print("\n✅ Entraînement SARSA terminé.")
    return q_sarsa

env = TrafficEnvironment()
q_sarsa = train_sarsa(env, episodes=1000)

# Affichage amélioré de la Q-table
print("\n🔍 Extrait Q-table SARSA :")
print("----------------------------------------------------")
print("|   État (N,S,E,W)   |  Gauche (0)  |  Droite (1)  |")
print("----------------------------------------------------")
for n in range(0, 10, 3):
    for s in range(0, 10, 3):
        for e in range(0, 10, 3):
            for w in range(0, 10, 3):
                left_value = q_sarsa[n, s, e, w, 0]
                right_value = q_sarsa[n, s, e, w, 1]
                print(f"|  ({n},{s},{e},{w})  |  {left_value:.2f}  |  {right_value:.2f}  |")
print("----------------------------------------------------")
# Out:
# ✅ Entraînement SARSA terminé.
#
# 🔍 Extrait Q-table SARSA :
# ----------------------------------------------------
# |   État (N,S,E,W)   |  Gauche (0)  |  Droite (1)  |
# ----------------------------------------------------
# |  (0,0,0,0)  |  16.95  |  2.42  |
# |  (0,0,0,3)  |  2.04  |  18.83  |
# |  (0,0,0,6)  |  0.11  |  0.00  |
# |  (0,0,0,9)  |  0.00  |  0.00  |
# |  (0,0,3,0)  |  1.11  |  19.81  |
# |  (0,0,3,3)  |  3.40  |  22.88  |
# |  (0,0,3,6)  |  0.17  |  9.95  |
# |  (0,0,3,9)  |  0.46  |  0.00  |
# |  (0,0,6,0)  |  0.60  |  0.00  |
# |  (0,0,6,3)  |  0.20  |  8.79  |
# |  (0,0,6,6)  |  0.03  |  6.54  |
# |  (0,0,6,9)  |  0.00  |  4.23  |
# |  (0,0,9,0)  |  0.00  |  0.00  |
# |  (0,0,9,3)  |  0.33  |  6.17  |
# |  (0,0,9,6)  |  1.94  |  0.00  |
# |  (0,0,9,9)  |  0.10  |  7.09  |
# |  (0,3,0,0)  |  0.84  |  19.03  |
# |  (0,3,0,3)  |  9.85  |  0.00  |
# |  (0,3,0,6)  |  0.00  |  0.00  |
# |  (0,3,0,9)  |  0.00  |  0.00  |
# |  (0,3,3,0)  |  0.00  |  12.13  |
# |  (0,3,3,3)  |  10.40  |  0.64  |
# |  (0,3,3,6)  |  0.65  |  0.00  |
# |  (0,3,3,9)  |  0.00  |  1.40  |
# |  (0,3,6,0)  |  0.00  |  0.31  |
# |  (0,3,6,3)  |  1.01  |  0.00  |
# |  (0,3,6,6)  |  0.50  |  0.00  |
# |  (0,3,6,9)  |  0.36  |  0.00  |
# |  (0,3,9,0)  |  0.00  |  0.00  |
# |  (0,3,9,3)  |  0.66  |  0.00  |
# |  (0,3,9,6)  |  0.24  |  2.23  |
# |  (0,3,9,9)  |  2.76  |  0.00  |
# |  (0,6,0,0)  |  0.98  |  0.00  |
# |  (0,6,0,3)  |  1.05  |  0.00  |
# |  (0,6,0,6)  |  0.00  |  0.00  |
# |  (0,6,0,9)  |  0.00  |  0.10  |
# |  (0,6,3,0)  |  0.78  |  0.00  |
# |  (0,6,3,3)  |  0.00  |  0.00  |
# |  (0,6,3,6)  |  0.00  |  0.00  |
# |  (0,6,3,9)  |  0.00  |  0.00  |
# |  (0,6,6,0)  |  0.00  |  0.00  |
# |  (0,6,6,3)  |  0.39  |  0.00  |
# |  (0,6,6,6)  |  0.30  |  0.00  |
# |  (0,6,6,9)  |  0.00  |  0.00  |
# |  (0,6,9,0)  |  0.00  |  0.00  |
# |  (0,6,9,3)  |  0.00  |  0.00  |
# |  (0,6,9,6)  |  0.00  |  0.00  |
# |  (0,6,9,9)  |  0.00  |  0.00  |
# |  (0,9,0,0)  |  0.00  |  0.00  |
# |  (0,9,0,3)  |  0.63  |  0.00  |
# |  (0,9,0,6)  |  0.00  |  0.00  |
# |  (0,9,0,9)  |  0.00  |  0.00  |
# |  (0,9,3,0)  |  0.00  |  0.00  |
# |  (0,9,3,3)  |  0.00  |  0.00  |
# |  (0,9,3,6)  |  0.00  |  0.00  |
# |  (0,9,3,9)  |  0.00  |  0.00  |
# |  (0,9,6,0)  |  0.00  |  0.00  |
# |  (0,9,6,3)  |  0.00  |  0.00  |
# |  (0,9,6,6)  |  0.00  |  0.00  |
# |  (0,9,6,9)  |  0.00  |  0.00  |
# |  (0,9,9,0)  |  0.10  |  0.00  |
# |  (0,9,9,3)  |  0.00  |  0.00  |
# |  (0,9,9,6)  |  0.00  |  0.00  |
# |  (0,9,9,9)  |  0.00  |  0.00  |
# |  (3,0,0,0)  |  11.75  |  2.29  |
# |  (3,0,0,3)  |  1.38  |  11.17  |
# |  (3,0,0,6)  |  1.02  |  0.00  |
# |  (3,0,0,9)  |  0.00  |  0.33  |
# |  (3,0,3,0)  |  11.42  |  0.00  |
# |  (3,0,3,3)  |  2.60  |  10.79  |
# |  (3,0,3,6)  |  0.29  |  0.00  |
# |  (3,0,3,9)  |  0.00  |  0.00  |
# |  (3,0,6,0)  |  0.00  |  0.59  |
# |  (3,0,6,3)  |  0.32  |  0.00  |
# |  (3,0,6,6)  |  0.92  |  0.00  |
# |  (3,0,6,9)  |  0.30  |  0.00  |
# |  (3,0,9,0)  |  0.43  |  0.00  |
# |  (3,0,9,3)  |  0.35  |  0.00  |
# |  (3,0,9,6)  |  0.00  |  0.60  |
# |  (3,0,9,9)  |  1.75  |  0.00  |
# |  (3,3,0,0)  |  6.60  |  22.11  |
# |  (3,3,0,3)  |  2.30  |  14.08  |
# |  (3,3,0,6)  |  0.00  |  0.00  |
# |  (3,3,0,9)  |  0.00  |  0.00  |
# |  (3,3,3,0)  |  2.01  |  13.51  |
# |  (3,3,3,3)  |  6.44  |  1.15  |
# |  (3,3,3,6)  |  3.32  |  0.67  |
# |  (3,3,3,9)  |  1.15  |  0.00  |
# |  (3,3,6,0)  |  0.84  |  0.00  |
# |  (3,3,6,3)  |  0.00  |  0.00  |
# |  (3,3,6,6)  |  1.06  |  0.00  |
# |  (3,3,6,9)  |  0.89  |  0.00  |
# |  (3,3,9,0)  |  0.00  |  0.66  |
# |  (3,3,9,3)  |  0.30  |  0.40  |
# |  (3,3,9,6)  |  0.70  |  0.00  |
# |  (3,3,9,9)  |  1.34  |  0.00  |
# |  (3,6,0,0)  |  1.09  |  11.77  |
# |  (3,6,0,3)  |  2.82  |  0.00  |
# |  (3,6,0,6)  |  0.00  |  0.00  |
# |  (3,6,0,9)  |  0.00  |  0.00  |
# |  (3,6,3,0)  |  0.00  |  0.00  |
# |  (3,6,3,3)  |  0.00  |  0.00  |
# |  (3,6,3,6)  |  0.00  |  0.00  |
# |  (3,6,3,9)  |  0.00  |  0.00  |
# |  (3,6,6,0)  |  0.00  |  0.94  |
# |  (3,6,6,3)  |  0.00  |  0.00  |
# |  (3,6,6,6)  |  0.50  |  0.00  |
# |  (3,6,6,9)  |  0.00  |  0.00  |
# |  (3,6,9,0)  |  0.00  |  0.00  |
# |  (3,6,9,3)  |  0.00  |  0.00  |
# |  (3,6,9,6)  |  0.00  |  0.00  |
# |  (3,6,9,9)  |  0.00  |  0.00  |
# |  (3,9,0,0)  |  1.04  |  0.00  |
# |  (3,9,0,3)  |  0.00  |  0.00  |
# |  (3,9,0,6)  |  0.40  |  0.00  |
# |  (3,9,0,9)  |  0.00  |  0.00  |
# |  (3,9,3,0)  |  0.00  |  0.00  |
# |  (3,9,3,3)  |  0.00  |  0.20  |
# |  (3,9,3,6)  |  0.00  |  0.00  |
# |  (3,9,3,9)  |  0.00  |  0.00  |
# |  (3,9,6,0)  |  0.00  |  0.00  |
# |  (3,9,6,3)  |  0.00  |  0.00  |
# |  (3,9,6,6)  |  0.00  |  0.00  |
# |  (3,9,6,9)  |  0.00  |  0.00  |
# |  (3,9,9,0)  |  0.00  |  0.00  |
# |  (3,9,9,3)  |  0.00  |  0.00  |
# |  (3,9,9,6)  |  0.00  |  0.00  |
# |  (3,9,9,9)  |  0.00  |  0.00  |
# |  (6,0,0,0)  |  0.20  |  0.00  |
# |  (6,0,0,3)  |  0.88  |  0.00  |
# |  (6,0,0,6)  |  0.00  |  0.00  |
# |  (6,0,0,9)  |  0.00  |  0.00  |
# |  (6,0,3,0)  |  1.69  |  0.00  |
# |  (6,0,3,3)  |  1.43  |  0.00  |
# |  (6,0,3,6)  |  0.00  |  0.00  |
# |  (6,0,3,9)  |  0.00  |  0.00  |
# |  (6,0,6,0)  |  0.00  |  0.00  |
# |  (6,0,6,3)  |  0.10  |  0.00  |
# |  (6,0,6,6)  |  0.00  |  0.00  |
# |  (6,0,6,9)  |  0.00  |  0.00  |
# |  (6,0,9,0)  |  0.00  |  0.00  |
# |  (6,0,9,3)  |  0.00  |  1.06  |
# |  (6,0,9,6)  |  0.72  |  0.00  |
# |  (6,0,9,9)  |  0.00  |  0.00  |
# |  (6,3,0,0)  |  0.73  |  15.36  |
# |  (6,3,0,3)  |  0.20  |  0.00  |
# |  (6,3,0,6)  |  0.00  |  0.00  |
# |  (6,3,0,9)  |  0.00  |  0.00  |
# |  (6,3,3,0)  |  0.45  |  0.00  |
# |  (6,3,3,3)  |  1.89  |  0.00  |
# |  (6,3,3,6)  |  0.00  |  0.00  |
# |  (6,3,3,9)  |  0.00  |  0.00  |
# |  (6,3,6,0)  |  0.30  |  0.00  |
# |  (6,3,6,3)  |  0.00  |  0.00  |
# |  (6,3,6,6)  |  0.84  |  0.00  |
# |  (6,3,6,9)  |  0.69  |  0.00  |
# |  (6,3,9,0)  |  0.00  |  0.00  |
# |  (6,3,9,3)  |  0.00  |  0.00  |
# |  (6,3,9,6)  |  0.00  |  0.00  |
# |  (6,3,9,9)  |  0.00  |  0.00  |
# |  (6,6,0,0)  |  0.00  |  4.99  |
# |  (6,6,0,3)  |  0.00  |  0.00  |
# |  (6,6,0,6)  |  0.00  |  0.00  |
# |  (6,6,0,9)  |  0.00  |  0.00  |
# |  (6,6,3,0)  |  0.94  |  0.00  |
# |  (6,6,3,3)  |  0.00  |  0.00  |
# |  (6,6,3,6)  |  0.00  |  0.00  |
# |  (6,6,3,9)  |  0.72  |  0.00  |
# |  (6,6,6,0)  |  0.00  |  0.00  |
# |  (6,6,6,3)  |  0.00  |  0.00  |
# |  (6,6,6,6)  |  0.00  |  0.00  |
# |  (6,6,6,9)  |  0.00  |  0.00  |
# |  (6,6,9,0)  |  0.00  |  0.00  |
# |  (6,6,9,3)  |  0.00  |  0.00  |
# |  (6,6,9,6)  |  0.00  |  0.00  |
# |  (6,6,9,9)  |  0.50  |  0.00  |
# |  (6,9,0,0)  |  0.00  |  3.42  |
# |  (6,9,0,3)  |  0.00  |  0.88  |
# |  (6,9,0,6)  |  0.00  |  0.00  |
# |  (6,9,0,9)  |  0.00  |  0.00  |
# |  (6,9,3,0)  |  0.00  |  0.00  |
# |  (6,9,3,3)  |  0.00  |  0.00  |
# |  (6,9,3,6)  |  0.50  |  0.00  |
# |  (6,9,3,9)  |  0.00  |  0.00  |
# |  (6,9,6,0)  |  0.00  |  0.00  |
# |  (6,9,6,3)  |  0.00  |  0.00  |
# |  (6,9,6,6)  |  0.00  |  0.00  |
# |  (6,9,6,9)  |  0.00  |  0.00  |
# |  (6,9,9,0)  |  0.00  |  0.00  |
# |  (6,9,9,3)  |  0.00  |  0.00  |
# |  (6,9,9,6)  |  0.00  |  0.00  |
# |  (6,9,9,9)  |  0.00  |  0.00  |
# |  (9,0,0,0)  |  0.00  |  0.00  |
# |  (9,0,0,3)  |  0.66  |  0.00  |
# |  (9,0,0,6)  |  0.00  |  0.00  |
# |  (9,0,0,9)  |  0.00  |  0.00  |
# |  (9,0,3,0)  |  0.00  |  0.00  |
# |  (9,0,3,3)  |  0.40  |  0.00  |
# |  (9,0,3,6)  |  0.00  |  0.00  |
# |  (9,0,3,9)  |  0.00  |  0.00  |
# |  (9,0,6,0)  |  0.30  |  0.00  |
# |  (9,0,6,3)  |  0.00  |  0.00  |
# |  (9,0,6,6)  |  0.00  |  0.00  |
# |  (9,0,6,9)  |  0.00  |  0.00  |
# |  (9,0,9,0)  |  0.00  |  0.00  |
# |  (9,0,9,3)  |  0.00  |  0.00  |
# |  (9,0,9,6)  |  0.00  |  0.00  |
# |  (9,0,9,9)  |  0.00  |  0.00  |
# |  (9,3,0,0)  |  0.44  |  0.00  |
# |  (9,3,0,3)  |  0.00  |  0.40  |
# |  (9,3,0,6)  |  0.40  |  0.00  |
# |  (9,3,0,9)  |  0.00  |  0.00  |
# |  (9,3,3,0)  |  0.00  |  0.00  |
# |  (9,3,3,3)  |  0.00  |  0.00  |
# |  (9,3,3,6)  |  0.00  |  0.00  |
# |  (9,3,3,9)  |  0.00  |  0.00  |
# |  (9,3,6,0)  |  0.00  |  0.00  |
# |  (9,3,6,3)  |  0.40  |  0.00  |
# |  (9,3,6,6)  |  0.00  |  0.00  |
# |  (9,3,6,9)  |  0.00  |  0.00  |
# |  (9,3,9,0)  |  0.50  |  0.00  |
# |  (9,3,9,3)  |  0.00  |  0.00  |
# |  (9,3,9,6)  |  0.00  |  0.00  |
# |  (9,3,9,9)  |  0.00  |  0.00  |
# |  (9,6,0,0)  |  0.00  |  2.47  |
# |  (9,6,0,3)  |  0.00  |  0.00  |
# |  (9,6,0,6)  |  0.00  |  0.00  |
# |  (9,6,0,9)  |  0.00  |  0.00  |
# |  (9,6,3,0)  |  0.00  |  0.00  |
# |  (9,6,3,3)  |  0.00  |  0.00  |
# |  (9,6,3,6)  |  0.00  |  0.00  |
# |  (9,6,3,9)  |  0.00  |  0.00  |
# |  (9,6,6,0)  |  0.67  |  0.00  |
# |  (9,6,6,3)  |  0.00  |  0.00  |
# |  (9,6,6,6)  |  0.00  |  0.00  |
# |  (9,6,6,9)  |  0.00  |  0.00  |
# |  (9,6,9,0)  |  0.64  |  0.00  |
# |  (9,6,9,3)  |  0.00  |  0.00  |
# |  (9,6,9,6)  |  0.00  |  0.00  |
# |  (9,6,9,9)  |  0.00  |  0.00  |
# |  (9,9,0,0)  |  0.09  |  5.61  |
# |  (9,9,0,3)  |  1.04  |  0.00  |
# |  (9,9,0,6)  |  0.00  |  0.00  |
# |  (9,9,0,9)  |  0.00  |  0.00  |
# |  (9,9,3,0)  |  0.00  |  0.00  |
# |  (9,9,3,3)  |  0.50  |  0.00  |
# |  (9,9,3,6)  |  0.60  |  0.00  |
# |  (9,9,3,9)  |  0.00  |  0.00  |
# |  (9,9,6,0)  |  0.00  |  0.00  |
# |  (9,9,6,3)  |  0.00  |  0.00  |
# |  (9,9,6,6)  |  0.00  |  0.40  |
# |  (9,9,6,9)  |  0.00  |  0.00  |
# |  (9,9,9,0)  |  0.00  |  0.00  |
# |  (9,9,9,3)  |  0.00  |  0.00  |
# |  (9,9,9,6)  |  0.00  |  0.00  |
# |  (9,9,9,9)  |  0.00  |  0.00  |
# ----------------------------------------------------

# %% [markdown]
# ## Exercice 4 : Analyse et Visualisation des Résultats

# %%
def train_q_learning(env, episodes=1000, alpha=0.1, gamma=0.9, epsilon=1.0, decay=0.995, min_epsilon=0.01):
    global q_table
    rewards_per_episode = []

    for episode in range(episodes):
        state = env.reset()
        state = np.clip(state, 0, 9)
        total_reward = 0

        for step in range(100):
            n, s, e, w = state
            if np.random.rand() < epsilon:
                action = np.random.choice([0, 1])
            else:
                action = np.argmax(q_table[n, s, e, w])

            next_state, reward = env.step(action)
            next_state = np.clip(next_state, 0, 9)
            n2, s2, e2, w2 = next_state

            best_next = np.max(q_table[n2, s2, e2, w2])
            q_table[n, s, e, w, action] += alpha * (reward + gamma * best_next - q_table[n, s, e, w, action])

            state = next_state
            total_reward += reward

        epsilon = max(min_epsilon, epsilon * decay)
        rewards_per_episode.append(total_reward)

    return q_table, rewards_per_episode

# %%
def train_sarsa(env, episodes=1000, alpha=0.1, gamma=0.9, epsilon=1.0, decay=0.995, min_epsilon=0.01):
    global q_sarsa
    rewards_per_episode = []

    for episode in range(episodes):
        state = env.reset()
        state = np.clip(state, 0, 9)
        n, s, e, w = state

        if np.random.rand() < epsilon:
            action = np.random.choice([0, 1])
        else:
            action = np.argmax(q_sarsa[n, s, e, w])

        total_reward = 0

        for step in range(100):
            next_state, reward = env.step(action)
            next_state = np.clip(next_state, 0, 9)
            n2, s2, e2, w2 = next_state

            if np.random.rand() < epsilon:
                next_action = np.random.choice([0, 1])
            else:
                next_action = np.argmax(q_sarsa[n2, s2, e2, w2])

            q_sarsa[n, s, e, w, action] += alpha * (
                reward + gamma * q_sarsa[n2, s2, e2, w2, next_action] - q_sarsa[n, s, e, w, action]
            )

            state = next_state
            n, s, e, w = state
            action = next_action
            total_reward += reward

        epsilon = max(min_epsilon, epsilon * decay)
        rewards_per_episode.append(total_reward)

    return q_sarsa, rewards_per_episode

# %%
env = TrafficEnvironment()

# Entraînement
q_table, q_learning_rewards = train_q_learning(env, episodes=1000)
q_sarsa, sarsa_rewards = train_sarsa(env, episodes=1000)

# Affichage graphique
plt.figure(figsize=(10, 5))
plt.plot(q_learning_rewards, label="Q-Learning")
plt.plot(sarsa_rewards, label="SARSA")
plt.xlabel("Épisodes")
plt.ylabel("Récompense cumulative par épisode")
plt.title("Comparaison Q-Learning vs SARSA")
plt.legend()
plt.grid()
plt.show()
