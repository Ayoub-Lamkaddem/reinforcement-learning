# %% [markdown]
# # APPRENTISSAGE PROFOND POUR LES JEUX - TP 4

# %% [markdown]
# ## Exercice 1: Initialisation de l'environnement et des structures de données

# %%
import gymnasium as gym
import numpy as np

# Initialisation de l'environnement Taxi
env = gym.make("Taxi-v3")

# Taille de l'espace d'états et d'actions
state_size = env.observation_space.n  # 500 états
action_size = env.action_space.n      # 6 actions possibles

# Affichage formaté
print("\n" + "=" * 50)
print("🚕 INITIALISATION DE L'ENVIRONNEMENT TAXI-V3")
print("=" * 50)
print(f"📌 Nombre total d'états   : {state_size}")
print(f"🎮 Nombre total d'actions : {action_size}")

# Création d'une table de politique : probas égales pour chaque action
policy_table = np.full((state_size, action_size), 1.0 / action_size)

# Création d'une table de valeurs initialisée à zéro
value_table = np.zeros(state_size)

# Affichage des premières lignes sous forme de tableau clair
print("\n📊 Extrait de la policy_table (probabilités d'action) :")
print("État | Action 0 | Action 1 | Action 2 | Action 3 | Action 4 | Action 5")
print("-" * 65)
for i in range(5):  # Afficher seulement les 5 premiers états
    print(f"{i:>4} | {' | '.join(f'{p:.2f}' for p in policy_table[i])}")

print("\n📈 Extrait de la value_table (valeurs associées aux états) :")
print("État | Valeur")
print("-" * 20)
for i in range(5):  # Afficher seulement les 5 premiers états
    print(f"{i:>4} | {value_table[i]:.2f}")

print("\n✅ Initialisation terminée ! 🚀")
# Out:
# ==================================================
# 🚕 INITIALISATION DE L'ENVIRONNEMENT TAXI-V3
# ==================================================
# 📌 Nombre total d'états   : 500
# 🎮 Nombre total d'actions : 6
#
# 📊 Extrait de la policy_table (probabilités d'action) :
# État | Action 0 | Action 1 | Action 2 | Action 3 | Action 4 | Action 5
# -----------------------------------------------------------------
#    0 | 0.17 | 0.17 | 0.17 | 0.17 | 0.17 | 0.17
#    1 | 0.17 | 0.17 | 0.17 | 0.17 | 0.17 | 0.17
#    2 | 0.17 | 0.17 | 0.17 | 0.17 | 0.17 | 0.17
#    3 | 0.17 | 0.17 | 0.17 | 0.17 | 0.17 | 0.17
#    4 | 0.17 | 0.17 | 0.17 | 0.17 | 0.17 | 0.17
#
# 📈 Extrait de la value_table (valeurs associées aux états) :
# État | Valeur
# --------------------
#    0 | 0.00
#    1 | 0.00
#    2 | 0.00
#    3 | 0.00
#    4 | 0.00
#
# ✅ Initialisation terminée ! 🚀

# %% [markdown]
# ## Exercice 2: Exploration et collecte d'épisodes

# %%
#import gym

# Initialisation de l'environnement
env = gym.make("Taxi-v3")

num_episodes = 20

print("\n" + "=" * 50)
print("🚕 SIMULATION DE L'AGENT DANS ENVIRONNEMENT TAXI-V3")
print("=" * 50)

for episode in range(num_episodes):
    state, _ = env.reset()
    done = False
    total_reward = 0
    step = 0

    print(f"\n🎬 Épisode {episode + 1} | 🚀 Démarrage de la simulation...")
    print("-" * 50)

    while not done:
        action = env.action_space.sample()  # Action aléatoire
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        print(f"🛑 Étape {step:02d} | 🕹 Action : {action} | ⭐ Récompense : {reward:+d}")
        total_reward += reward
        state = next_state
        step += 1

    print("-" * 50)
    print(f"✅ Épisode {episode + 1} terminé en {step} étapes | 🎯 Récompense totale : {total_reward}")

print("\n🏁 Simulation terminée ! 🚀")
# Out:
# ==================================================
# 🚕 SIMULATION DE L'AGENT DANS ENVIRONNEMENT TAXI-V3
# ==================================================
#
# 🎬 Épisode 1 | 🚀 Démarrage de la simulation...
# --------------------------------------------------
# 🛑 Étape 00 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 01 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 02 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 03 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 04 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 05 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 06 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 07 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 08 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 09 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 10 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 11 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 12 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 13 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 14 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 15 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 16 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 17 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 18 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 19 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 20 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 21 | 🕹 Action : 4 | ⭐ Récompense : -1
# 🛑 Étape 22 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 23 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 24 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 25 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 26 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 27 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 28 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 29 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 30 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 31 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 32 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 33 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 34 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 35 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 36 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 37 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 38 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 39 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 40 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 41 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 42 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 43 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 44 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 45 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 46 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 47 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 48 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 49 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 50 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 51 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 52 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 53 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 54 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 55 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 56 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 57 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 58 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 59 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 60 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 61 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 62 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 63 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 64 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 65 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 66 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 67 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 68 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 69 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 70 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 71 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 72 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 73 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 74 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 75 | 🕹 Action : 5 | ⭐ Récompense : -1
# 🛑 Étape 76 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 77 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 78 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 79 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 80 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 81 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 82 | 🕹 Action : 4 | ⭐ Récompense : -1
# 🛑 Étape 83 | 🕹 Action : 5 | ⭐ Récompense : -1
# 🛑 Étape 84 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 85 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 86 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 87 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 88 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 89 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 90 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 91 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 92 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 93 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 94 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 95 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 96 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 97 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 98 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 99 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 100 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 101 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 102 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 103 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 104 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 105 | 🕹 Action : 4 | ⭐ Récompense : -1
# 🛑 Étape 106 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 107 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 108 | 🕹 Action : 5 | ⭐ Récompense : -1
# 🛑 Étape 109 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 110 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 111 | 🕹 Action : 4 | ⭐ Récompense : -1
# 🛑 Étape 112 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 113 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 114 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 115 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 116 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 117 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 118 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 119 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 120 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 121 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 122 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 123 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 124 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 125 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 126 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 127 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 128 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 129 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 130 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 131 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 132 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 133 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 134 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 135 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 136 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 137 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 138 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 139 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 140 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 141 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 142 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 143 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 144 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 145 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 146 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 147 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 148 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 149 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 150 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 151 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 152 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 153 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 154 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 155 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 156 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 157 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 158 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 159 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 160 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 161 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 162 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 163 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 164 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 165 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 166 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 167 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 168 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 169 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 170 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 171 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 172 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 173 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 174 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 175 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 176 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 177 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 178 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 179 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 180 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 181 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 182 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 183 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 184 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 185 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 186 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 187 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 188 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 189 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 190 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 191 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 192 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 193 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 194 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 195 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 196 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 197 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 198 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 199 | 🕹 Action : 5 | ⭐ Récompense : -10
# --------------------------------------------------
# ✅ Épisode 1 terminé en 200 étapes | 🎯 Récompense totale : -722
#
# 🎬 Épisode 2 | 🚀 Démarrage de la simulation...
# --------------------------------------------------
# 🛑 Étape 00 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 01 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 02 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 03 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 04 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 05 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 06 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 07 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 08 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 09 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 10 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 11 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 12 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 13 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 14 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 15 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 16 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 17 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 18 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 19 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 20 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 21 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 22 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 23 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 24 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 25 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 26 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 27 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 28 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 29 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 30 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 31 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 32 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 33 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 34 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 35 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 36 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 37 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 38 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 39 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 40 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 41 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 42 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 43 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 44 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 45 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 46 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 47 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 48 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 49 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 50 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 51 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 52 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 53 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 54 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 55 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 56 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 57 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 58 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 59 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 60 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 61 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 62 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 63 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 64 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 65 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 66 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 67 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 68 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 69 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 70 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 71 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 72 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 73 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 74 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 75 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 76 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 77 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 78 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 79 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 80 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 81 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 82 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 83 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 84 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 85 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 86 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 87 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 88 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 89 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 90 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 91 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 92 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 93 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 94 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 95 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 96 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 97 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 98 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 99 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 100 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 101 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 102 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 103 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 104 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 105 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 106 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 107 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 108 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 109 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 110 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 111 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 112 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 113 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 114 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 115 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 116 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 117 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 118 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 119 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 120 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 121 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 122 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 123 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 124 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 125 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 126 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 127 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 128 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 129 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 130 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 131 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 132 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 133 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 134 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 135 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 136 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 137 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 138 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 139 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 140 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 141 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 142 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 143 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 144 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 145 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 146 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 147 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 148 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 149 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 150 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 151 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 152 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 153 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 154 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 155 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 156 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 157 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 158 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 159 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 160 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 161 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 162 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 163 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 164 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 165 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 166 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 167 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 168 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 169 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 170 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 171 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 172 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 173 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 174 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 175 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 176 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 177 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 178 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 179 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 180 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 181 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 182 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 183 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 184 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 185 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 186 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 187 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 188 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 189 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 190 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 191 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 192 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 193 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 194 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 195 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 196 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 197 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 198 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 199 | 🕹 Action : 5 | ⭐ Récompense : -10
# --------------------------------------------------
# ✅ Épisode 2 terminé en 200 étapes | 🎯 Récompense totale : -857
#
# 🎬 Épisode 3 | 🚀 Démarrage de la simulation...
# --------------------------------------------------
# 🛑 Étape 00 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 01 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 02 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 03 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 04 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 05 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 06 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 07 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 08 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 09 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 10 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 11 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 12 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 13 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 14 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 15 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 16 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 17 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 18 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 19 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 20 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 21 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 22 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 23 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 24 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 25 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 26 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 27 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 28 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 29 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 30 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 31 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 32 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 33 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 34 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 35 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 36 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 37 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 38 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 39 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 40 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 41 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 42 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 43 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 44 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 45 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 46 | 🕹 Action : 4 | ⭐ Récompense : -1
# 🛑 Étape 47 | 🕹 Action : 5 | ⭐ Récompense : -1
# 🛑 Étape 48 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 49 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 50 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 51 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 52 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 53 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 54 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 55 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 56 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 57 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 58 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 59 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 60 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 61 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 62 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 63 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 64 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 65 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 66 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 67 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 68 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 69 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 70 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 71 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 72 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 73 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 74 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 75 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 76 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 77 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 78 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 79 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 80 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 81 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 82 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 83 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 84 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 85 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 86 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 87 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 88 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 89 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 90 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 91 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 92 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 93 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 94 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 95 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 96 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 97 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 98 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 99 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 100 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 101 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 102 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 103 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 104 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 105 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 106 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 107 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 108 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 109 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 110 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 111 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 112 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 113 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 114 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 115 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 116 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 117 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 118 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 119 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 120 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 121 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 122 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 123 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 124 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 125 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 126 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 127 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 128 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 129 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 130 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 131 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 132 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 133 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 134 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 135 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 136 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 137 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 138 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 139 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 140 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 141 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 142 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 143 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 144 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 145 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 146 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 147 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 148 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 149 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 150 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 151 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 152 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 153 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 154 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 155 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 156 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 157 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 158 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 159 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 160 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 161 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 162 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 163 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 164 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 165 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 166 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 167 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 168 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 169 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 170 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 171 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 172 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 173 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 174 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 175 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 176 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 177 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 178 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 179 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 180 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 181 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 182 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 183 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 184 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 185 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 186 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 187 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 188 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 189 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 190 | 🕹 Action : 4 | ⭐ Récompense : -1
# 🛑 Étape 191 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 192 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 193 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 194 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 195 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 196 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 197 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 198 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 199 | 🕹 Action : 1 | ⭐ Récompense : -1
# --------------------------------------------------
# ✅ Épisode 3 terminé en 200 étapes | 🎯 Récompense totale : -677
#
# 🎬 Épisode 4 | 🚀 Démarrage de la simulation...
# --------------------------------------------------
# 🛑 Étape 00 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 01 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 02 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 03 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 04 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 05 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 06 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 07 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 08 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 09 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 10 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 11 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 12 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 13 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 14 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 15 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 16 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 17 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 18 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 19 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 20 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 21 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 22 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 23 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 24 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 25 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 26 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 27 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 28 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 29 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 30 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 31 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 32 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 33 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 34 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 35 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 36 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 37 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 38 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 39 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 40 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 41 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 42 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 43 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 44 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 45 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 46 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 47 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 48 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 49 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 50 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 51 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 52 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 53 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 54 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 55 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 56 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 57 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 58 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 59 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 60 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 61 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 62 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 63 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 64 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 65 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 66 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 67 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 68 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 69 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 70 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 71 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 72 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 73 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 74 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 75 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 76 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 77 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 78 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 79 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 80 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 81 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 82 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 83 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 84 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 85 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 86 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 87 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 88 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 89 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 90 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 91 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 92 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 93 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 94 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 95 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 96 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 97 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 98 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 99 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 100 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 101 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 102 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 103 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 104 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 105 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 106 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 107 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 108 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 109 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 110 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 111 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 112 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 113 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 114 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 115 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 116 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 117 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 118 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 119 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 120 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 121 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 122 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 123 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 124 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 125 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 126 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 127 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 128 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 129 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 130 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 131 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 132 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 133 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 134 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 135 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 136 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 137 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 138 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 139 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 140 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 141 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 142 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 143 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 144 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 145 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 146 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 147 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 148 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 149 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 150 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 151 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 152 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 153 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 154 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 155 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 156 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 157 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 158 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 159 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 160 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 161 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 162 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 163 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 164 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 165 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 166 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 167 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 168 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 169 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 170 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 171 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 172 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 173 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 174 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 175 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 176 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 177 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 178 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 179 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 180 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 181 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 182 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 183 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 184 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 185 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 186 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 187 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 188 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 189 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 190 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 191 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 192 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 193 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 194 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 195 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 196 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 197 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 198 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 199 | 🕹 Action : 1 | ⭐ Récompense : -1
# --------------------------------------------------
# ✅ Épisode 4 terminé en 200 étapes | 🎯 Récompense totale : -875
#
# 🎬 Épisode 5 | 🚀 Démarrage de la simulation...
# --------------------------------------------------
# 🛑 Étape 00 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 01 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 02 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 03 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 04 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 05 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 06 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 07 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 08 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 09 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 10 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 11 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 12 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 13 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 14 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 15 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 16 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 17 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 18 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 19 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 20 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 21 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 22 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 23 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 24 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 25 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 26 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 27 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 28 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 29 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 30 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 31 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 32 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 33 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 34 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 35 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 36 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 37 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 38 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 39 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 40 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 41 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 42 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 43 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 44 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 45 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 46 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 47 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 48 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 49 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 50 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 51 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 52 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 53 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 54 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 55 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 56 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 57 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 58 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 59 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 60 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 61 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 62 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 63 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 64 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 65 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 66 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 67 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 68 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 69 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 70 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 71 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 72 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 73 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 74 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 75 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 76 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 77 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 78 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 79 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 80 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 81 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 82 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 83 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 84 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 85 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 86 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 87 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 88 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 89 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 90 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 91 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 92 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 93 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 94 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 95 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 96 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 97 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 98 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 99 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 100 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 101 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 102 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 103 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 104 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 105 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 106 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 107 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 108 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 109 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 110 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 111 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 112 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 113 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 114 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 115 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 116 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 117 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 118 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 119 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 120 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 121 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 122 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 123 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 124 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 125 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 126 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 127 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 128 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 129 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 130 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 131 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 132 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 133 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 134 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 135 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 136 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 137 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 138 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 139 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 140 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 141 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 142 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 143 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 144 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 145 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 146 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 147 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 148 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 149 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 150 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 151 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 152 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 153 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 154 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 155 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 156 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 157 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 158 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 159 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 160 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 161 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 162 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 163 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 164 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 165 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 166 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 167 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 168 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 169 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 170 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 171 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 172 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 173 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 174 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 175 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 176 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 177 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 178 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 179 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 180 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 181 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 182 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 183 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 184 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 185 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 186 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 187 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 188 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 189 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 190 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 191 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 192 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 193 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 194 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 195 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 196 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 197 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 198 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 199 | 🕹 Action : 5 | ⭐ Récompense : -10
# --------------------------------------------------
# ...
# 🛑 Étape 67 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 68 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 69 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 70 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 71 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 72 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 73 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 74 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 75 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 76 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 77 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 78 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 79 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 80 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 81 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 82 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 83 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 84 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 85 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 86 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 87 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 88 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 89 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 90 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 91 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 92 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 93 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 94 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 95 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 96 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 97 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 98 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 99 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 100 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 101 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 102 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 103 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 104 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 105 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 106 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 107 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 108 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 109 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 110 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 111 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 112 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 113 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 114 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 115 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 116 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 117 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 118 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 119 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 120 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 121 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 122 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 123 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 124 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 125 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 126 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 127 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 128 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 129 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 130 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 131 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 132 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 133 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 134 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 135 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 136 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 137 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 138 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 139 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 140 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 141 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 142 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 143 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 144 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 145 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 146 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 147 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 148 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 149 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 150 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 151 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 152 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 153 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 154 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 155 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 156 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 157 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 158 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 159 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 160 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 161 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 162 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 163 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 164 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 165 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 166 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 167 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 168 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 169 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 170 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 171 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 172 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 173 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 174 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 175 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 176 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 177 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 178 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 179 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 180 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 181 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 182 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 183 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 184 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 185 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 186 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 187 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 188 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 189 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 190 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 191 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 192 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 193 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 194 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 195 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 196 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 197 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 198 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 199 | 🕹 Action : 5 | ⭐ Récompense : -10
# --------------------------------------------------
# ✅ Épisode 19 terminé en 200 étapes | 🎯 Récompense totale : -695
#
# 🎬 Épisode 20 | 🚀 Démarrage de la simulation...
# --------------------------------------------------
# 🛑 Étape 00 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 01 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 02 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 03 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 04 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 05 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 06 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 07 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 08 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 09 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 10 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 11 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 12 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 13 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 14 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 15 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 16 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 17 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 18 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 19 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 20 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 21 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 22 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 23 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 24 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 25 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 26 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 27 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 28 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 29 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 30 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 31 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 32 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 33 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 34 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 35 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 36 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 37 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 38 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 39 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 40 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 41 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 42 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 43 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 44 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 45 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 46 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 47 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 48 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 49 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 50 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 51 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 52 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 53 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 54 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 55 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 56 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 57 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 58 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 59 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 60 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 61 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 62 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 63 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 64 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 65 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 66 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 67 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 68 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 69 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 70 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 71 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 72 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 73 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 74 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 75 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 76 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 77 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 78 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 79 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 80 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 81 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 82 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 83 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 84 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 85 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 86 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 87 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 88 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 89 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 90 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 91 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 92 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 93 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 94 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 95 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 96 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 97 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 98 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 99 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 100 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 101 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 102 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 103 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 104 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 105 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 106 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 107 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 108 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 109 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 110 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 111 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 112 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 113 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 114 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 115 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 116 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 117 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 118 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 119 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 120 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 121 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 122 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 123 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 124 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 125 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 126 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 127 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 128 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 129 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 130 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 131 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 132 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 133 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 134 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 135 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 136 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 137 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 138 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 139 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 140 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 141 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 142 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 143 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 144 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 145 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 146 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 147 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 148 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 149 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 150 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 151 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 152 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 153 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 154 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 155 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 156 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 157 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 158 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 159 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 160 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 161 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 162 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 163 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 164 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 165 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 166 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 167 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 168 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 169 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 170 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 171 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 172 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 173 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 174 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 175 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 176 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 177 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 178 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 179 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 180 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 181 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 182 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 183 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 184 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 185 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 186 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 187 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 188 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 189 | 🕹 Action : 4 | ⭐ Récompense : -10
# 🛑 Étape 190 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 191 | 🕹 Action : 1 | ⭐ Récompense : -1
# 🛑 Étape 192 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 193 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 194 | 🕹 Action : 2 | ⭐ Récompense : -1
# 🛑 Étape 195 | 🕹 Action : 5 | ⭐ Récompense : -10
# 🛑 Étape 196 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 197 | 🕹 Action : 3 | ⭐ Récompense : -1
# 🛑 Étape 198 | 🕹 Action : 0 | ⭐ Récompense : -1
# 🛑 Étape 199 | 🕹 Action : 4 | ⭐ Récompense : -10
# --------------------------------------------------
# ✅ Épisode 20 terminé en 200 étapes | 🎯 Récompense totale : -749
#
# 🏁 Simulation terminée ! 🚀

# %% [markdown]
# ## Exercice 3 : Mise à jour de la politique avec PРО

# %%
import numpy as np

# --- Affichage des résultats avec mise en forme ---
def display_results(value_table, policy_table, episode_rewards_list):
    print("\n" + "="*50)
    print("🎯 RÉSULTATS DE L'ENTRAÎNEMENT PPO")
    print("="*50)

    # Statistiques générales
    print(f"\n📊 Nombre total d'épisodes : {len(episode_rewards_list)}")
    print(f"📈 Récompense moyenne finale : {np.mean(episode_rewards_list[-100:]):.2f}")
    print(f"🏅 Meilleure récompense atteinte : {np.max(episode_rewards_list):.2f}")

    # Affichage des 10 premières valeurs de la value_table
    print("\n📌 Extrait de la Value Table (10 premiers états) :")
    print("-" * 50)
    for i in range(10):
        print(f"🟢 État {i} → Valeur estimée : {value_table[i]:.3f}")

    # Affichage de la politique pour les 5 premiers états
    print("\n📌 Politique extraite (probabilités d'action) :")
    print("-" * 50)
    for s in range(5):
        policy_str = " | ".join([f"A{a}: {p:.2f}" for a, p in enumerate(policy_table[s])])
        print(f"🔹 État {s} → {policy_str}")

    print("\n✅ Entraînement terminé avec succès ! 🎉")

# Appel de la fonction d'affichage après l'entraînement
display_results(value_table, policy_table, episode_rewards_list)
# Out:
# ==================================================
# 🎯 RÉSULTATS DE L'ENTRAÎNEMENT PPO
# ==================================================
#
# 📊 Nombre total d'épisodes : 1000
# 📈 Récompense moyenne finale : -709.67
# 🏅 Meilleure récompense atteinte : -200.00
#
# 📌 Extrait de la Value Table (10 premiers états) :
# --------------------------------------------------
# 🟢 État 0 → Valeur estimée : 0.000
# 🟢 État 1 → Valeur estimée : -158.332
# 🟢 État 2 → Valeur estimée : -124.896
# 🟢 État 3 → Valeur estimée : -89.856
# 🟢 État 4 → Valeur estimée : -217.364
# 🟢 État 5 → Valeur estimée : 0.000
# 🟢 État 6 → Valeur estimée : -91.120
# 🟢 État 7 → Valeur estimée : -17.964
# 🟢 État 8 → Valeur estimée : -91.743
# 🟢 État 9 → Valeur estimée : -91.743
#
# 📌 Politique extraite (probabilités d'action) :
# --------------------------------------------------
# 🔹 État 0 → A0: 0.17 | A1: 0.17 | A2: 0.17 | A3: 0.17 | A4: 0.17 | A5: 0.17
# 🔹 État 1 → A0: 0.00 | A1: 0.00 | A2: 1.00 | A3: 0.00 | A4: 0.00 | A5: 0.00
# 🔹 État 2 → A0: 0.81 | A1: 0.19 | A2: 0.00 | A3: 0.00 | A4: 0.00 | A5: 0.00
# 🔹 État 3 → A0: 0.00 | A1: 0.00 | A2: 0.00 | A3: 0.00 | A4: 0.00 | A5: 1.00
# 🔹 État 4 → A0: 1.00 | A1: 0.00 | A2: 0.00 | A3: 0.00 | A4: 0.00 | A5: 0.00
#
# ✅ Entraînement terminé avec succès ! 🎉

# %% [markdown]
# ## Exercice 4: Évaluation de l'agent après entraînement

# %%
import numpy as np

# Nombre d'épisodes pour l'évaluation
num_eval_episodes = 20

# --- Fonction pour évaluer un agent donné ---
def evaluate_agent(policy_table, mode="greedy", episodes=20):
    total_rewards = []
    
    for ep in range(episodes):
        state, _ = env.reset()
        done = False
        total_reward = 0

        while not done:
            if mode == "greedy":
                action = np.argmax(policy_table[state])  # action max
            elif mode == "random":
                action = env.action_space.sample()       # action aléatoire
            else:
                raise ValueError("Mode inconnu : choisir 'greedy' ou 'random'")
            
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total_reward += reward
            state = next_state
        
        total_rewards.append(total_reward)
    
    return total_rewards

# --- Évaluation AVANT entraînement (agent aléatoire) ---
print("\n" + "="*40)
print("📢 Évaluation de l'agent avant entraînement (aléatoire)")
print("="*40)

random_rewards = evaluate_agent(policy_table, mode="random", episodes=num_eval_episodes)

print("\n🎯 Résultats de l'agent aléatoire")
print("-" * 40)
print(f"📊 Récompenses obtenues : {random_rewards}")
print(f"📈 Récompense moyenne : {np.mean(random_rewards):.2f}")
print("="*40)

# --- Évaluation APRÈS entraînement (agent PPO) ---
print("\n" + "="*40)
print("🏆 Évaluation de l'agent après entraînement (PPO)")
print("="*40)

ppo_rewards = evaluate_agent(policy_table, mode="greedy", episodes=num_eval_episodes)

print("\n🚀 Résultats de l'agent entraîné (PPO)")
print("-" * 40)
print(f"📊 Récompenses obtenues : {ppo_rewards}")
print(f"📈 Récompense moyenne : {np.mean(ppo_rewards):.2f}")
print("="*40)

# --- Comparaison ---
improvement = np.mean(ppo_rewards) - np.mean(random_rewards)

print("\n🔍 Comparaison des performances")
print("-" * 40)
print(f"📉 Récompense moyenne (aléatoire) : {np.mean(random_rewards):.2f}")
print(f"📈 Récompense moyenne (PPO) : {np.mean(ppo_rewards):.2f}")
print(f"📊 Amélioration moyenne : {improvement:.2f}")
print("="*40)
# Out:
# ========================================
# 📢 Évaluation de l'agent avant entraînement (aléatoire)
# ========================================
#
# 🎯 Résultats de l'agent aléatoire
# ----------------------------------------
# 📊 Récompenses obtenues : [-821, -848, -785, -803, -785, -758, -677, -875, -749, -857, -758, -812, -758, -812, -884, -821, -758, -713, -776, -686]
# 📈 Récompense moyenne : -786.80
# ========================================
#
# ========================================
# 🏆 Évaluation de l'agent après entraînement (PPO)
# ========================================
#
# 🚀 Résultats de l'agent entraîné (PPO)
# ----------------------------------------
# 📊 Récompenses obtenues : [-200, -200, -200, -200, -200, -200, -200, -200, -200, -200, -200, -200, -2000, -200, -1991, -200, -2000, -200, -200, -200]
# 📈 Récompense moyenne : -469.55
# ========================================
#
# 🔍 Comparaison des performances
# ----------------------------------------
# 📉 Récompense moyenne (aléatoire) : -786.80
# 📈 Récompense moyenne (PPO) : -469.55
# 📊 Amélioration moyenne : 317.25
# ========================================
